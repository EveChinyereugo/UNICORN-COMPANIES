# %%
# import the necessary libraries
import numpy as np
import pandas as pd
# for visuals
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load and read data file
Unicorn_Companies = pd.read_csv(r'C:\Users\OBC 8\Desktop\python\Unicorn_Companies.csv')
Unicorn_Companies
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B  2017-04-07          Artificial intelligence
# 1          SpaceX     $100B  2012-12-01                            Other
# 2           SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3          Stripe      $95B  2014-01-23                          Fintech
# 4          Klarna      $46B  2011-12-12                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B  2017-06-29  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B  2017-04-18  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B  2021-05-06                Consumer & retail
# 1072         Zopa       $1B  2021-10-19                          Fintech
# 1073        Zwift       $1B  2020-09-16  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded Funding  \
# ...

# %% [markdown]
# Data Understanding
#
# --- Dataframe shape,head and tail,dt types and data description

# %%
shape = Unicorn_Companies.shape
print(shape)
# Out:
# (1074, 10)

# %%
Unicorn_Companies.head()
# Out:
#      Company Valuation Date Joined                         Industry  \
# 0  Bytedance     $180B  2017-04-07          Artificial intelligence
# 1     SpaceX     $100B  2012-12-01                            Other
# 2      SHEIN     $100B  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe      $95B  2014-01-23                          Fintech
# 4     Klarna      $46B  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded Funding  \
# 0        Beijing          China           Asia          2012     $8B
# 1      Hawthorne  United States  North America          2002     $7B
# 2       Shenzhen          China           Asia          2008     $2B
# 3  San Francisco  United States  North America          2010     $2B
# 4      Stockholm         Sweden         Europe          2005     $4B
#
#                                     Select Investors
# 0  Sequoia Capital China, SIG Asia Investments, S...
# ...

# %%
Unicorn_Companies.dtypes
# Out:
# Company             object
# Valuation           object
# Date Joined         object
# Industry            object
# City                object
# Country             object
# Continent           object
# Year Founded         int64
# Funding             object
# Select Investors    object
# dtype: object

# %%
# An onverview of dataframe
Unicorn_Companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country           1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
# statistical descriptive analysis of numerical features/variables.
Unicorn_Companies.describe()
# Out:
#        Year Founded
# count   1074.000000
# mean    2012.895717
# std        5.698573
# min     1919.000000
# 25%     2011.000000
# 50%     2014.000000
# 75%     2016.000000
# max     2021.000000

# %%
# To find out if there are duplicates
Unicorn_Companies.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1069    False
# 1070    False
# 1071    False
# 1072    False
# 1073    False
# Length: 1074, dtype: bool

# %%
Unicorn_Companies.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Industry', 'City', 'Country',
#        'Continent', 'Year Founded', 'Funding', 'Select Investors'],
#       dtype='object')

# %%
# To find out for missing values
Unicorn_Companies.isna().sum()
# Out:
# Company              0
# Valuation            0
# Date Joined          0
# Industry             0
# City                16
# Country              0
# Continent            0
# Year Founded         0
# Funding              0
# Select Investors     1
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis
# Creating relationship, insight and visualization of our dataset using ---- Univariante ---- Biavariante ---- Multivariant

# %% [markdown]
# Question 1- Which unicorn companies have had the biggest Return On Investment?

# %%
# taking out the  "$", "B", "M" from Funding column 

Unicorn_Companies.Funding = Unicorn_Companies.Funding.str.replace("$","")

Unicorn_Companies.Funding = Unicorn_Companies.Funding.str.replace("B",'0'*9)

Unicorn_Companies.Funding = Unicorn_Companies.Funding.str.replace("M",'0'*6)
# Out:
# C:\Users\OBC 8\AppData\Local\Temp\ipykernel_42948\2595133753.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Unicorn_Companies.Funding = Unicorn_Companies.Funding.str.replace("$","")

# %%
import pandas as pd

# Assuming you have a DataFrame called 'Unicorn_Companies' and you want to convert the 'Funding' column to float
# Replace 'Unknown' with NaN in the 'Funding' column
Unicorn_Companies['Funding'] = pd.to_numeric(Unicorn_Companies['Funding'], errors='coerce')

# Now you can convert the column to float
Unicorn_Companies['Funding'] = Unicorn_Companies['Funding'].astype(float)

# %%
# Convert the 'Funding' column to float
Unicorn_Companies['Funding'] = Unicorn_Companies['Funding'].astype(float)

# %%
# taking out the  "$", "B", "M" from Valuation column 
Unicorn_Companies['Valuation'] = Unicorn_Companies['Valuation'].astype(str).str.replace('$', '').str.replace('B', '0'*9).str.replace('M', '0'*6)
# Out:
# C:\Users\OBC 8\AppData\Local\Temp\ipykernel_42948\2841285780.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Unicorn_Companies['Valuation'] = Unicorn_Companies['Valuation'].astype(str).str.replace('$', '').str.replace('B', '0'*9).str.replace('M', '0'*6)

# %%
# convert the 'Valuation' column to float
Unicorn_Companies['Valuation'] = Unicorn_Companies['Valuation'].astype(float)

# %%
# Calculate ROI for each company

Unicorn_Companies['ROI'] = Unicorn_Companies['Valuation'] - Unicorn_Companies['Funding']
 
# Sort the dataframe by ROI in descending order and select the top 10 companies

sorted_df = Unicorn_Companies.sort_values('ROI', ascending=False)

 
# Display the top 10 companies with the biggest ROI

print(sorted_df[['Company', 'ROI']])

sorted_df = Unicorn_Companies.sort_values('ROI', ascending=True).head(10)
# Out:
#               Company           ROI
# 0           Bytedance  1.720000e+11
# 2               SHEIN  9.800000e+10
# 1              SpaceX  9.300000e+10
# 3              Stripe  9.300000e+10
# 4              Klarna  4.200000e+10
# ...               ...           ...
# 866          Assembly           NaN
# 890      Carson Group           NaN
# 945   Iodine Software           NaN
# 947      Kendra Scott           NaN
# 1002           Poizon           NaN
#
# [1074 rows x 2 columns]

# %%
# calculate ROI for each company

Unicorn_Companies['ROI'] = Unicorn_Companies['Valuation'] - Unicorn_Companies['Funding']

# Sort the dataframe by ROI in descending order and select the top 10 companies

sorted_df = Unicorn_Companies.sort_values('ROI', ascending=False).head(10)

 
# Create a horizontal bar plot

plt.figure(figsize=(10, 6))

plt.barh(sorted_df['Company'], sorted_df['ROI'])

plt.xlabel('Return on Investment (in billions)')

plt.ylabel('Company')

plt.title('Top 10 Unicorn Companies with the Biggest Return on Investment')

plt.show()

# %% [markdown]
# Question 2 -How long does it usually take for a company to become a unicorn? Has it always been this way?

# %%
# We need to find the lenght of time it takes for a company to be a unicorn
# first we need to Convert the JoinDate column to datetime


Unicorn_Companies["Date Joined"] = pd.to_datetime(Unicorn_Companies["Date Joined"])

 
# then crete a `YearsToJoin` column.

 
Unicorn_Companies["Years To Join"] = Unicorn_Companies["Date Joined"].dt.year - Unicorn_Companies["Year Founded"]


# Display the first few rows of `companies`to confirm that the new column did get added.
Unicorn_Companies.head()
# Out:
#      Company     Valuation Date Joined                         Industry  \
# 0  Bytedance  1.800000e+11  2017-04-07          Artificial intelligence
# 1     SpaceX  1.000000e+11  2012-12-01                            Other
# 2      SHEIN  1.000000e+11  2018-07-03  E-commerce & direct-to-consumer
# 3     Stripe  9.500000e+10  2014-01-23                          Fintech
# 4     Klarna  4.600000e+10  2011-12-12                          Fintech
#
#             City        Country      Continent  Year Founded       Funding  \
# 0        Beijing          China           Asia          2012  8.000000e+09
# 1      Hawthorne  United States  North America          2002  7.000000e+09
# 2       Shenzhen          China           Asia          2008  2.000000e+09
# 3  San Francisco  United States  North America          2010  2.000000e+09
# 4      Stockholm         Sweden         Europe          2005  4.000000e+09
#
#                                     Select Investors           ROI  \
# ...

# %%
Unicorn_Companies['Years To Join'].value_counts()
# Out:
#  6     138
#  5     129
#  4     125
#  7     107
#  3      98
#  8      88
#  2      68
#  10     62
#  9      52
#  11     36
#  1      36
#  14     20
#  13     19
#  12     17
#  17     10
#  16     10
#  15      9
#  0       9
#  19      7
#  18      6
#  20      6
#  21      6
#  22      5
#  37      2
#  25      2
#  27      2
# -4       1
#  26      1
#  24      1
#  98      1
#  28      1
# Name: Years To Join, dtype: int64

# %%
import matplotlib.pyplot as plt

 
grouped_df = Unicorn_Companies.groupby('Year Founded')['Years To Join'].mean()

plt.plot(grouped_df.index, grouped_df.values)
plt.xlabel('Year Founded')
plt.ylabel('Average Years to Join')
plt.title('Average Years to Join for Unicorn Companies by Year Founded')
plt.show()

# %% [markdown]
# ## Question 3 -which countries have the most unicorns industry hub - city and country

# %%
# To know the countries with the most unicorns as well as industry hub city
Unicorn_Companies['Country'].value_counts().head(10)
# Out:
# United States     562
# China             173
# India              65
# United Kingdom     43
# Germany            26
# France             24
# Israel             20
# Canada             19
# Brazil             16
# Singapore          12
# Name: Country, dtype: int64

# %%
# Countries with the most Unicorn
Unicorn_Companies['Country'].value_counts().tail(10)
# Out:
# Bermuda           1
# Lithuania         1
# Malaysia          1
# Senegal           1
# Bahamas           1
# Luxembourg        1
# Nigeria           1
# Czech Republic    1
# Croatia           1
# Italy             1
# Name: Country, dtype: int64

# %%
import seaborn as sns

top_countries = Unicorn_Companies['Country'].value_counts().head(5).index
top_companies = Unicorn_Companies[Unicorn_Companies['Country'].isin(top_countries)]
sns.countplot(y='Country', hue='Industry', data=top_companies, order=top_countries)
# Out:
# <Axes: xlabel='count', ylabel='Country'>

# %%
# Cities with the most Unicorn
Unicorn_Companies['City'].value_counts().head(10)
# Out:
# San Francisco    152
# New York         103
# Beijing           63
# Shanghai          44
# London            34
# Bengaluru         29
# Shenzhen          19
# Paris             19
# Palo Alto         18
# Berlin            17
# Name: City, dtype: int64

# %%
# Cities with the most Unicorn
Unicorn_Companies['City'].value_counts().tail(10)
# Out:
# Lausanne         1
# Aberdeen         1
# Nashville        1
# Lysaker          1
# Richmond         1
# Santa Barbara    1
# Altrincham       1
# Northbrook       1
# Cincinnati       1
# Milpitas         1
# Name: City, dtype: int64

# %%
import seaborn as sns

top_countries = Unicorn_Companies['City'].value_counts().head(5).index
top_companies = Unicorn_Companies[Unicorn_Companies['City'].isin(top_countries)]
sns.countplot(y='City', hue='Industry', data=top_companies, order=top_countries)
# Out:
# <Axes: xlabel='count', ylabel='City'>

# %%
# To show unicorn Companies alongside their continent


import matplotlib.pyplot as plt

 
# Create a bar chart of the number of unicorn companies in each continent
Unicorn_Companies['Continent'].value_counts().plot(kind='bar', color='purple')

 
# Set the plot title and axis labels
plt.title('Number of Unicorn Companies by Continent', fontsize=16)
plt.xlabel('Continent', fontsize=14)
plt.ylabel('Number of Companies', fontsize=14)

 
# Set the font size of the tick labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

 
# Add a grid to the plot
plt.grid(axis='y')

 
# Display the plot
plt.show()

# %%
# To show the highest unicorn companies by Industry

ax = Unicorn_Companies['Industry'].value_counts()\
        .head(10)\
        .plot(kind='bar',title='Top 5 highest Unicorn driven Industry ')
ax.set_xlabel('Industry')
ax.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# ## Question - 4. Which Investors have funded the most unicorns?

# %%
# Investor that funded the most unicorn companies

# Calculate Select Investor by their Company funding.

top_investors = Unicorn_Companies['Select Investors'].value_counts().head(5).index.tolist()

print(f"The top five select investors who funded unicorn companies are: {top_investors}")
# Out:
# The top five select investors who funded unicorn companies are: ['Sequoia Capital', 'Pelion Venture Partners, Foundation Capital, Thoma Bravo', 'Insight Partners, Sequoia Capital, Index Ventures', 'Speedinvest, Valar Ventures, Uniqa Ventures', 'SoftBank Group']

# %%
import matplotlib.pyplot as plt

# Get the data for the top five select investors
top_investors = Unicorn_Companies['Select Investors'].value_counts().head(5).index.tolist()
investor_data = Unicorn_Companies[Unicorn_Companies['Select Investors'].isin(top_investors)].groupby('Select Investors')['Funding'].sum().sort_values(ascending=False)

# Create a donut chart of the investor data
plt.figure(figsize=(8, 8))
plt.pie(investor_data.values, labels=investor_data.index, autopct='%1.1f%%', startangle=90, pctdistance=0.85, labeldistance=1.05)
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Total Funding by Select Investor (Top 5)')
plt.show()

# %%
# filter the unicorn_data dataframe to include only rows where the 'Select Investors' column is null
null_investors = Unicorn_Companies[Unicorn_Companies['Select Investors'].isnull()]

# print the resulting dataframe
(null_investors)
# Out:
#               Company     Valuation Date Joined                     Industry  \
# 629  LinkSure Network  1.000000e+09  2015-01-01  Mobile & telecommunications
#
#          City Country Continent  Year Founded     Funding Select Investors  \
# 629  Shanghai   China      Asia          2013  52000000.0              NaN
#
#              ROI  Years To Join
# 629  948000000.0              2

# %%
# Sort the dataframe by Select Investors in descending order and select the top 10 companies
sorted_df = Unicorn_Companies.sort_values('Funding', ascending=False).head(10)


# Create a horizontal bar plot
plt.figure(figsize=(10, 6))
plt.barh(sorted_df['Select Investors'], sorted_df['Funding'])
plt.xlabel('Investors with the most funding (in billions)')
plt.ylabel('Select Invesor')
plt.title('Top 10 Select Investors and their funding')
plt.show()

# %%
# Showing the various continent and their fundings

Funding_by_continent = Unicorn_Companies.groupby('Continent')['Funding'].sum().sort_values(ascending=True)
print(Funding_by_continent)
# Out:
# Continent
# Africa           1.317000e+09
# Oceania          2.708000e+09
# South America    1.313300e+10
# Europe           8.753600e+10
# Asia             1.940410e+11
# North America    2.930850e+11
# Name: Funding, dtype: float64

# %%
# Create a DataFrame for the industry counts

industry_counts = Unicorn_Companies['Industry'].value_counts().sort_values(ascending=True)

# Plot the bar chart

plt.figure(figsize=(12, 6))

industry_counts.plot(kind='bar')

plt.xlabel('Industry')

plt.ylabel('Count')

plt.title('Number of Companies per Industry')

plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ## Recommendations
#
# - Unicorn Companies should leverage data analytics to identify companies that have high-growth potential. This can be done by analyzing market trends, consumer behavior, and other relevant data points to identify companies that are likely to experience significant growth in the future.
#
# - Unicorn Companies should diversify their investment portfolio to reduce risk and maximize returns. This can be done by investing in a mix of early-stage, mid-stage, and late-stage companies across different industries and geographies.
#
# - Unicorn Companies should prioritize investing in companies with experienced leadership teams. This is because experienced leaders are more likely to make sound business decisions and navigate the challenges that come with scaling a company.
#
# - Unicorn Companies should continuously evaluate and adjust their business models based on data-driven insights. This can be done by analyzing performance metrics, customer feedback, and other relevant data points to identify areas for improvement and make informed decisions about how to optimize their business models.
